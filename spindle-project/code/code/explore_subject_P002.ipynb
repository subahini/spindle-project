# %%
from scipy.io import loadmat

# Load your .mat file
mat = loadmat("../data/raw/SeLECTS_P002_1_epochsScoring_artndxn.mat")
epo = loadmat("../data/raw/SeLECTS_P002_1_epochsScoring .mat")
# Show all top-level keys
print("📦 Keys in the .mat file:")
print(mat.keys())
print(epo.keys())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/Master Project/spindle-project/.venv/lib/python3.12/site-packages/scipy/io/matlab/_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw/SeLECTS_P002_1_epochsScoring_artndxn.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from scipy.io import loadmat
#       3 # Load your .mat file
# ----> 4 mat = loadmat("../data/raw/SeLECTS_P002_1_epochsScoring_artndxn.mat")
#       5 epo = loadmat("../data/raw/SeLECTS_P002_1_epochsScoring .mat")
#       6 # Show all top-level keys
#
# ...

# %%
artndxn = mat['artndxn'].flatten()

print(f"🔍 Total epochs: {len(artndxn)}")
print(f"🟢 Clean epochs (0): {(artndxn == 0).sum()}")
print(f"🔴 Artifact epochs (1): {(artndxn == 1).sum()}")

# Plot it
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 1))
plt.plot(artndxn, '|', markersize=10)
plt.title("Artifact Index (1 = bad, 0 = clean)")
plt.xlabel("Epoch index")
plt.yticks([0, 1])
plt.show()
# Out:
# 🔍 Total epochs: 18867
# 🟢 Clean epochs (0): 7753
# 🔴 Artifact epochs (1): 11114

# %%
artndxn = epo['__function_workspace__'].flatten()

print(f"🔍 Total epochs: {len(artndxn)}")
print(f"🟢 Clean epochs (0): {(artndxn == 0).sum()}")
print(f"🔴 Artifact epochs (1): {(artndxn == 1).sum()}")

# Plot it
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 1))
plt.plot(artndxn, '|', markersize=10)
plt.title("Artifact Index (1 = bad, 0 = clean)")
plt.xlabel("Epoch index")
plt.yticks([0, 1])
plt.show()
# Out:
# 🔍 Total epochs: 11016
# 🟢 Clean epochs (0): 8791
# 🔴 Artifact epochs (1): 1046

# %%
epochs = epo['__function_workspace__']

print(f"🔎 Shape of epochsScoring: {epochs.shape}")
print(f"Example fields: {epochs.dtype}")
# Out:
# 🔎 Shape of epochsScoring: (1, 11016)
# Example fields: uint8

# %%
# Show fields for the first epoch
first_epoch = epochs[0, 0]  # MATLAB struct array is 2D
print(first_epoch.dtype.names)

# Try accessing stage or start time
if 'stage' in first_epoch.dtype.names:
    print("Sleep stage:", first_epoch['stage'])
# Out:
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 6
#       3 print(first_epoch.dtype.names)
#       5 # Try accessing stage or start time
# ----> 6 if 'stage' in first_epoch.dtype.names:
#       7     print("Sleep stage:", first_epoch['stage'])
#
# TypeError: argument of type 'NoneType' is not iterable
